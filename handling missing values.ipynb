# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()## tlls about missing values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
##dropping rows with missing entries
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna().shape ##dropping rows
# Out:
# (182, 15)

# %%
df.dropna(axis=1).shape ##dropping columns
# Out:
# (891, 11)

# %%
## handling mising values by mean
df['age'].isnull().sum()
# Out:
# np.int64(177)

# %%
df['age_mean']=df['age'].fillna(df['age'].mean)

# %%
df[['age_mean','age']]
# Out:
#                                               age_mean   age
# 0                                                 22.0  22.0
# 1                                                 38.0  38.0
# 2                                                 26.0  26.0
# 3                                                 35.0  35.0
# 4                                                 35.0  35.0
# ..                                                 ...   ...
# 886                                               27.0  27.0
# 887                                               19.0  19.0
# 888  <bound method Series.mean of 0      22.0\n1   ...   NaN
# 889                                               26.0  26.0
# 890                                               32.0  32.0
#
# [891 rows x 2 columns]

# %%
##by median
df['med_age']=df.age.fillna(df.age.median())
df[['age_mean','age','med_age']]
# Out:
#                                               age_mean   age  med_age
# 0                                                 22.0  22.0     22.0
# 1                                                 38.0  38.0     38.0
# 2                                                 26.0  26.0     26.0
# 3                                                 35.0  35.0     35.0
# 4                                                 35.0  35.0     35.0
# ..                                                 ...   ...      ...
# 886                                               27.0  27.0     27.0
# 887                                               19.0  19.0     19.0
# 888  <bound method Series.mean of 0      22.0\n1   ...   NaN     28.0
# 889                                               26.0  26.0     26.0
# 890                                               32.0  32.0     32.0
#
# [891 rows x 3 columns]

# %%
##by mode

# %%
df[df['embarked'].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone age_mean  med_age
# 61   woman       False    B         NaN   yes   True     38.0     38.0
# 829  woman       False    B         NaN   yes   True     62.0     62.0

# %%
df.embarked.mode()[0]
# Out:
# 'S'

# %%
df['embarked_mode']=df.embarked.fillna(df.embarked.mode()[0])
df[['age_mean','age','med_age','embarked_mode']]
# Out:
# age_mean           0
# age              177
# med_age            0
# embarked_mode      0
# dtype: int64
